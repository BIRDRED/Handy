# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')

# Defina a semente para garantir a reprodutibilidade
tf.random.set_seed(42)

# Caminho para a pasta de dados
train_path = '/content/drive/MyDrive/Projeto Final/Dataset/Dataset_crop/train'

# Tamanho das imagens de entrada
input_size = (128, 128, 3)

# Set batch size
BATCH_SIZE = 64

# Por exemplo, você pode usar 20% dos dados para validação
# Normalização + aumento de dados
train_datagen = ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,
    shear_range=0.4,
    rotation_range=15,
    vertical_flip=True,
    validation_split=0.3
)

# Normalização
val_datagen = ImageDataGenerator(rescale=1./255)

# Divida os dados de treinamento em treinamento e validação
train_data = train_datagen.flow_from_directory(
    train_path,
    target_size=input_size[:2],
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    class_mode='binary',
    shuffle=True,  # Embaralhar os dados de treinamento
    subset='training',  # Especifica o conjunto de treinamento
    seed=42,  # Pode especificar uma semente para reprodução
)

val_data = train_datagen.flow_from_directory(
    train_path,
    target_size=input_size[:2],
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    class_mode='binary',
    shuffle=False,  # Não embaralhar os dados de validação
    subset='validation',  # Especifica o conjunto de validação
    seed=42  # Use a mesma semente para garantir a consistência
)

# Crie o modelo
model = Sequential()

model.add(Conv2D(32, (3, 3), input_shape=input_size, activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1, activation='sigmoid', name='classification'))

epochs = 30
lr = 1e-4
# Compile o modelo
model.compile(loss='binary_crossentropy',
              optimizer=Adam(learning_rate=lr),
              metrics=['accuracy'])

# Treine o modelo
history = model.fit(
    train_data,
    validation_data=val_data,
    batch_size = BATCH_SIZE,
    epochs=epochs  # Você pode ajustar o número de épocas conforme necessário
)

# Plote as curvas de treinamento de precisão e perda
plt.figure(figsize=(12, 4))

# Gráfico de precisão
plt.subplot(1, 2, 1)
plt.title(f'Acc - ConvNet, (128x128), batch = {BATCH_SIZE}, lr = {lr}, RGB')
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# Gráfico de perda
plt.subplot(1, 2, 2)
plt.title(f'Loss - ConvNet, (128x128), batch = {BATCH_SIZE}, lr = {lr}, RGB')
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# Avalie o modelo nos dados de validação
val_loss, val_acc = model.evaluate(val_data, verbose=2)
print(f'Val accuracy: {val_acc}')

# Salve o modelo treinado
#model.save('/content/drive/MyDrive/Projeto Final/trained_model.h5')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 813 images belonging to 2 classes.
# Found 347 images belonging to 2 classes.
# Epoch 1/30
# 13/13 [==============================] - 42s 3s/step - loss: 0.7001 - accuracy: 0.5215 - val_loss: 0.6880 - val_accuracy: 0.5418
# Epoch 2/30
# 13/13 [==============================] - 40s 3s/step - loss: 0.6921 - accuracy: 0.5474 - val_loss: 0.6770 - val_accuracy: 0.5677
# Epoch 3/30
# 13/13 [==============================] - 40s 3s/step - loss: 0.6848 - accuracy: 0.5646 - val_loss: 0.6751 - val_accuracy: 0.5648
# Epoch 4/30
# 13/13 [==============================] - 40s 3s/step - loss: 0.6760 - accuracy: 0.5756 - val_loss: 0.6715 - val_accuracy: 0.6830
# Epoch 5/30
# 13/13 [==============================] - 40s 3s/step - loss: 0.6737 - accuracy: 0.5707 - val_loss: 0.6626 - val_accuracy: 0.5908
# Epoch 6/30
# 13/13 [==============================] - 40s 3s/step - loss: 0.6567 - accuracy: 0.6199 - val_loss: 0.6560 - val_accuracy: 0.6167
# Epoch 7/30
# 13/13 [==============================] - 40s 3s/step - loss: 0.6410 - accuracy: 0.6421 - val_loss: 0.6483 - val_accuracy: 0.6427
# Epoch 8/30
# 13/13 [==============================] - 39s 3s/step - loss: 0.6259 - accuracy: 0.6974 - val_loss: 0.6661 - val_accuracy: 0.5677
# Epoch 9/30
# 13/13 [==============================] - 39s 3s/step - loss: 0.6106 - accuracy: 0.6876 - val_loss: 0.6575 - val_accuracy: 0.6167
# Epoch 10/30
# 13/13 [==============================] - 41s 3s/step - loss: 0.5782 - accuracy: 0.7306 - val_loss: 0.6758 - val_accuracy: 0.5994
# Epoch 11/30
# 13/13 [==============================] - 40s 3s/step - loss: 0.5818 - accuracy: 0.7122 - val_loss: 0.6706 - val_accuracy: 0.6023
# Epoch 12/30
# 13/13 [==============================] - 40s 3s/step - loss: 0.5614 - accuracy: 0.7319 - val_loss: 0.6527 - val_accuracy: 0.6542
# Epoch 13/30
# 13/13 [==============================] - 39s 3s/step - loss: 0.5531 - accuracy: 0.7392 - val_loss: 0.6455 - val_accuracy: 0.6571
# Epoch 14/30
# 13/13 [==============================] - 40s 3s/step - loss: 0.5431 - accuracy: 0.7355 - val_loss: 0.6667 - val_accuracy: 0.6398
# Epoch 15/30
# 13/13 [==============================] - 40s 3s/step - loss: 0.5279 - accuracy: 0.7577 - val_loss: 0.6731 - val_accuracy: 0.6484
# Epoch 16/30
# 13/13 [==============================] - 38s 3s/step - loss: 0.5246 - accuracy: 0.7392 - val_loss: 0.6392 - val_accuracy: 0.6542
# Epoch 17/30
# 13/13 [==============================] - 38s 3s/step - loss: 0.5082 - accuracy: 0.7774 - val_loss: 0.6671 - val_accuracy: 0.6455
# Epoch 18/30
# 13/13 [==============================] - 38s 3s/step - loss: 0.5028 - accuracy: 0.7663 - val_loss: 0.6452 - val_accuracy: 0.6686
# Epoch 19/30
# 13/13 [==============================] - 39s 3s/step - loss: 0.4926 - accuracy: 0.7724 - val_loss: 0.6376 - val_accuracy: 0.6542
# Epoch 20/30
# 13/13 [==============================] - 40s 3s/step - loss: 0.5075 - accuracy: 0.7663 - val_loss: 0.6819 - val_accuracy: 0.6484
# Epoch 21/30
# 13/13 [==============================] - 39s 3s/step - loss: 0.4841 - accuracy: 0.7786 - val_loss: 0.6699 - val_accuracy: 0.6542
# Epoch 22/30
# 13/13 [==============================] - 38s 3s/step - loss: 0.4815 - accuracy: 0.7872 - val_loss: 0.6814 - val_accuracy: 0.6542
# Epoch 23/30
# 13/13 [==============================] - 38s 3s/step - loss: 0.4739 - accuracy: 0.7897 - val_loss: 0.6595 - val_accuracy: 0.6484
# Epoch 24/30
# 13/13 [==============================] - 40s 3s/step - loss: 0.4622 - accuracy: 0.8057 - val_loss: 0.6410 - val_accuracy: 0.6715
# Epoch 25/30
# 13/13 [==============================] - 41s 3s/step - loss: 0.4861 - accuracy: 0.7823 - val_loss: 0.6848 - val_accuracy: 0.6311
# Epoch 26/30
# 13/13 [==============================] - 39s 3s/step - loss: 0.4982 - accuracy: 0.7688 - val_loss: 0.6795 - val_accuracy: 0.6542
# Epoch 27/30
# 13/13 [==============================] - 40s 3s/step - loss: 0.4831 - accuracy: 0.7872 - val_loss: 0.6565 - val_accuracy: 0.6427
# Epoch 28/30
# 13/13 [==============================] - 40s 3s/step - loss: 0.4579 - accuracy: 0.7995 - val_loss: 0.6780 - val_accuracy: 0.6484
# Epoch 29/30
# 13/13 [==============================] - 39s 3s/step - loss: 0.4575 - accuracy: 0.7958 - val_loss: 0.6831 - val_accuracy: 0.6398
# Epoch 30/30
# 13/13 [==============================] - 40s 3s/step - loss: 0.4564 - accuracy: 0.8081 - val_loss: 0.6682 - val_accuracy: 0.6657
# 6/6 - 8s - loss: 0.6697 - accuracy: 0.6571 - 8s/epoch - 1s/step
# Val accuracy: 0.6570605039596558

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')

# Defina a semente para garantir a reprodutibilidade
tf.random.set_seed(42)

# Caminho para a pasta de dados
train_path = '/content/drive/MyDrive/Projeto Final/Dataset/Dataset_crop/train'

# Tamanho das imagens de entrada
input_size = (64, 64, 3)

# Set batch size
BATCH_SIZE = 64

# Por exemplo, você pode usar 20% dos dados para validação
# Normalização + aumento de dados
train_datagen = ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,
    shear_range=0.4,
    rotation_range=15,
    vertical_flip=True,
    validation_split=0.3
)

# Normalização
val_datagen = ImageDataGenerator(rescale=1./255)

# Divida os dados de treinamento em treinamento e validação
train_data = train_datagen.flow_from_directory(
    train_path,
    target_size=input_size[:2],
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    class_mode='binary',
    shuffle=True,  # Embaralhar os dados de treinamento
    subset='training',  # Especifica o conjunto de treinamento
    seed=42,  # Pode especificar uma semente para reprodução
)

val_data = train_datagen.flow_from_directory(
    train_path,
    target_size=input_size[:2],
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    class_mode='binary',
    shuffle=False,  # Não embaralhar os dados de validação
    subset='validation',  # Especifica o conjunto de validação
    seed=42  # Use a mesma semente para garantir a consistência
)

# Crie o modelo
model = Sequential()

model.add(Conv2D(32, (3, 3), input_shape=input_size, activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1, activation='sigmoid', name='classification'))

epochs = 30
lr = 1e-4
# Compile o modelo
model.compile(loss='binary_crossentropy',
              optimizer=Adam(learning_rate=lr),
              metrics=['accuracy'])

# Treine o modelo
history = model.fit(
    train_data,
    validation_data=val_data,
    batch_size = BATCH_SIZE,
    epochs=epochs  # Você pode ajustar o número de épocas conforme necessário
)

# Plote as curvas de treinamento de precisão e perda
plt.figure(figsize=(12, 4))

# Gráfico de precisão
plt.subplot(1, 2, 1)
plt.title(f'Acc - ConvNet, (64x64), batch = {BATCH_SIZE}, lr = {lr}, RGB')
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# Gráfico de perda
plt.subplot(1, 2, 2)
plt.title(f'Loss - ConvNet, (64x64), batch = {BATCH_SIZE}, lr = {lr}, RGB')
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# Avalie o modelo nos dados de validação
val_loss, val_acc = model.evaluate(val_data, verbose=2)
print(f'Val accuracy: {val_acc}')

# Salve o modelo treinado
#model.save('/content/drive/MyDrive/Projeto Final/trained_model.h5')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 813 images belonging to 2 classes.
# Found 347 images belonging to 2 classes.
# Epoch 1/30
# 13/13 [==============================] - 38s 3s/step - loss: 0.6910 - accuracy: 0.5474 - val_loss: 0.6841 - val_accuracy: 0.5648
# Epoch 2/30
# 13/13 [==============================] - 34s 3s/step - loss: 0.6873 - accuracy: 0.5461 - val_loss: 0.6809 - val_accuracy: 0.5562
# Epoch 3/30
# 13/13 [==============================] - 34s 3s/step - loss: 0.6839 - accuracy: 0.5584 - val_loss: 0.6770 - val_accuracy: 0.5793
# Epoch 4/30
# 13/13 [==============================] - 35s 3s/step - loss: 0.6849 - accuracy: 0.5707 - val_loss: 0.6732 - val_accuracy: 0.5706
# Epoch 5/30
# 13/13 [==============================] - 35s 3s/step - loss: 0.6757 - accuracy: 0.5744 - val_loss: 0.6695 - val_accuracy: 0.6628
# Epoch 6/30
# 13/13 [==============================] - 37s 3s/step - loss: 0.6759 - accuracy: 0.5670 - val_loss: 0.6659 - val_accuracy: 0.6138
# Epoch 7/30
# 13/13 [==============================] - 33s 3s/step - loss: 0.6671 - accuracy: 0.6101 - val_loss: 0.6603 - val_accuracy: 0.6311
# Epoch 8/30
# 13/13 [==============================] - 37s 3s/step - loss: 0.6706 - accuracy: 0.5929 - val_loss: 0.6580 - val_accuracy: 0.6398
# Epoch 9/30
# 13/13 [==============================] - 38s 3s/step - loss: 0.6550 - accuracy: 0.6322 - val_loss: 0.6565 - val_accuracy: 0.6369
# Epoch 10/30
# 13/13 [==============================] - 34s 3s/step - loss: 0.6379 - accuracy: 0.6617 - val_loss: 0.6630 - val_accuracy: 0.5965
# Epoch 11/30
# 13/13 [==============================] - 34s 3s/step - loss: 0.6420 - accuracy: 0.6581 - val_loss: 0.6561 - val_accuracy: 0.6282
# Epoch 12/30
# 13/13 [==============================] - 34s 3s/step - loss: 0.6432 - accuracy: 0.6298 - val_loss: 0.6514 - val_accuracy: 0.6455
# Epoch 13/30
# 13/13 [==============================] - 35s 3s/step - loss: 0.6251 - accuracy: 0.6544 - val_loss: 0.6497 - val_accuracy: 0.6254
# Epoch 14/30
# 13/13 [==============================] - 35s 3s/step - loss: 0.6205 - accuracy: 0.6740 - val_loss: 0.6602 - val_accuracy: 0.6340
# Epoch 15/30
# 13/13 [==============================] - 34s 3s/step - loss: 0.6172 - accuracy: 0.6654 - val_loss: 0.6450 - val_accuracy: 0.6484
# Epoch 16/30
# 13/13 [==============================] - 34s 3s/step - loss: 0.5937 - accuracy: 0.7109 - val_loss: 0.6485 - val_accuracy: 0.6599
# Epoch 17/30
# 13/13 [==============================] - 35s 3s/step - loss: 0.5821 - accuracy: 0.6999 - val_loss: 0.6449 - val_accuracy: 0.5965
# Epoch 18/30
# 13/13 [==============================] - 35s 3s/step - loss: 0.5587 - accuracy: 0.7294 - val_loss: 0.6472 - val_accuracy: 0.6484
# Epoch 19/30
# 13/13 [==============================] - 33s 3s/step - loss: 0.5532 - accuracy: 0.7392 - val_loss: 0.6372 - val_accuracy: 0.6081
# Epoch 20/30
# 13/13 [==============================] - 34s 3s/step - loss: 0.5446 - accuracy: 0.7269 - val_loss: 0.6607 - val_accuracy: 0.6744
# Epoch 21/30
# 13/13 [==============================] - 33s 3s/step - loss: 0.5234 - accuracy: 0.7577 - val_loss: 0.6426 - val_accuracy: 0.6138
# Epoch 22/30
# 13/13 [==============================] - 34s 3s/step - loss: 0.5458 - accuracy: 0.7466 - val_loss: 0.6647 - val_accuracy: 0.6340
# Epoch 23/30
# 13/13 [==============================] - 34s 3s/step - loss: 0.5405 - accuracy: 0.7380 - val_loss: 0.6307 - val_accuracy: 0.6254
# Epoch 24/30
# 13/13 [==============================] - 34s 3s/step - loss: 0.5396 - accuracy: 0.7343 - val_loss: 0.6308 - val_accuracy: 0.6513
# Epoch 25/30
# 13/13 [==============================] - 34s 3s/step - loss: 0.5224 - accuracy: 0.7528 - val_loss: 0.6822 - val_accuracy: 0.5994
# Epoch 26/30
# 13/13 [==============================] - 35s 3s/step - loss: 0.5017 - accuracy: 0.7651 - val_loss: 0.6434 - val_accuracy: 0.6427
# Epoch 27/30
# 13/13 [==============================] - 35s 3s/step - loss: 0.5004 - accuracy: 0.7761 - val_loss: 0.6381 - val_accuracy: 0.6484
# Epoch 28/30
# 13/13 [==============================] - 34s 3s/step - loss: 0.5073 - accuracy: 0.7552 - val_loss: 0.6291 - val_accuracy: 0.6311
# Epoch 29/30
# 13/13 [==============================] - 34s 3s/step - loss: 0.5055 - accuracy: 0.7700 - val_loss: 0.6344 - val_accuracy: 0.6369
# Epoch 30/30
# 13/13 [==============================] - 34s 3s/step - loss: 0.4941 - accuracy: 0.7700 - val_loss: 0.6602 - val_accuracy: 0.6282
# 6/6 - 7s - loss: 0.6540 - accuracy: 0.6196 - 7s/epoch - 1s/step
# Val accuracy: 0.619596540927887
